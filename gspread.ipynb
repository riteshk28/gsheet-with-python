# %%
import pandas as pd
import gspread
from google.oauth2.service_account import Credentials

# %%
# importing the module 
import json 
  
# Opening JSON file 
with open('gittrial-281110-d80bc1ae9f69.json') as json_file: 
    keyfile = json.load(json_file)

# %%
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

'''keyfile_dict = {
  "type": "service_account",
  "project_id": "*****************************",
  "private_key_id": "*************************************",
  "private_key": "*****************************************",
  "client_email": "*****************************",
  "client_id": "************************",
  "auth_uri": "***************************",
  "token_uri": "**************************",
  "auth_provider_x509_cert_url": "******************************",
  "client_x509_cert_url": "************************************************"
}
'''
credentials = Credentials.from_service_account_info(
    keyfile, scopes=scope)

# %%
gc = gspread.authorize(credentials)

# %%
ws = gc.open("abandoned").worksheet("Sheet1")

# %%
df1 = pd.read_csv('converted.csv')

# %%
df1.head()
# Out:
#      id  tele_id  office_id      order_id                           plan_desc  \
# 0    95     6042          3  121672420517  Personalised Messaging (12 Months)
# 1  1252    49467          2  122103153648   Personalised Messaging (3 Months)
# 2  2294   231641          2  122431910172   Personalised Messaging (3 Months)
# 3  6927   234926         12  122717518313   Personalised Messaging (3 Months)
# 4  8622   311186          1  122925068125   Personalised Messaging (3 Months)
#
#        type  order_amount  amount  incentive_amount  \
# 0  outbound        3783.0  3783.0            3783.0
# 1  outbound        1658.0  1658.0            1658.0
# 2  outbound        1560.0  1560.0            1560.0
# 3  outbound        1463.0  1463.0            1463.0
# 4  outbound        1950.0  1950.0            1950.0
#
#               mode_of_payment            call_response   lead_owner  \
# 0  Cheque/Demand Draft Pickup             Already Paid    bhargabim
# ...

# %%
from gspread_dataframe import get_as_dataframe, set_with_dataframe

# %%
set_with_dataframe(ws, df1)

# %%
df2 = get_as_dataframe(ws)

# %%
df2.head()
# Out:
#      id  tele_id  office_id      order_id                           plan_desc  \
# 0    95     6042          3  121672420517  Personalised Messaging (12 Months)
# 1  1252    49467          2  122103153648   Personalised Messaging (3 Months)
# 2  2294   231641          2  122431910172   Personalised Messaging (3 Months)
# 3  6927   234926         12  122717518313   Personalised Messaging (3 Months)
# 4  8622   311186          1  122925068125   Personalised Messaging (3 Months)
#
#        type  order_amount  amount  incentive_amount  \
# 0  outbound        3783.0  3783.0            3783.0
# 1  outbound        1658.0  1658.0            1658.0
# 2  outbound        1560.0  1560.0            1560.0
# 3  outbound        1463.0  1463.0            1463.0
# 4  outbound        1950.0  1950.0            1950.0
#
#               mode_of_payment  ... Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# 0  Cheque/Demand Draft Pickup  ...         NaN         NaN         NaN
# ...
